# %%
import copernicusmarine
#copernicusmarine.login() # Nécessaire pour se logger sur le serveur de Copernicus Marine
from pprint import pprint

# %%
output_directory = '/Users/remyguillermin/Programmation/Stage/IGE-Stochastic/data/RAW/'
get_result = copernicusmarine.get(
    dataset_id='METOFFICE-GLO-SST-L4-REP-OBS-SST', # ID du dataset sur https://data.marine.copernicus.eu/products
    dry_run=False, # Si True, affiche les fichiers à télécharger sans les télécharger
    filter="*2018/*", # Filtre les fichiers à télécharger
    output_directory=output_directory, # Répertoire de sortie
    #create_file_list= output_directory + "files_to_download.txt", # Crée un fichier avec la liste des fichiers à télécharger
    no_directories=True, # Si True, télécharge les fichiers dans le répertoire de sortie sans créer de sous-répertoires
)

pprint(f"List of saved files: {get_result}")
# Out:
# INFO - 2025-03-04T12:58:29Z - Selected dataset version: "202003"
# INFO - 2025-03-04T12:58:29Z - Selected dataset part: "default"
# INFO - 2025-03-04T12:58:29Z - Listing files on remote server...
# 15it [00:05,  2.99it/s]
# Downloading files:  15%|█▌        | 56/365 [03:47<20:54,  4.06s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/anaconda3/envs/env-croco/lib/python3.13/site-packages/copernicusmarine/core_functions/utils.py:141, in run_concurrently(func, function_arguments, max_concurrent_requests, tdqm_bar_configuration)
#     137 future_to_url = (
#     138     executor.submit(func, *function_argument)
#     139     for function_argument in function_arguments
#     140 )
# --> 141 for future in concurrent.futures.as_completed(future_to_url):
#     142     data = future.result()
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     358 if timeout is None:
# --> 359     waiter.acquire()
#     360     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 output_directory = '/Users/remyguillermin/Programmation/Stage/IGE-Stochastic/data/RAW/'
# ----> 2 get_result = copernicusmarine.get(
#       3     dataset_id='METOFFICE-GLO-SST-L4-REP-OBS-SST', # ID du dataset sur https://data.marine.copernicus.eu/products
#       4     dry_run=False, # Si True, affiche les fichiers à télécharger sans les télécharger
#       5     filter="*2018/*", # Filtre les fichiers à télécharger
#       6     output_directory=output_directory, # Répertoire de sortie
#       7     #create_file_list= output_directory + "files_to_download.txt", # Crée un fichier avec la liste des fichiers à télécharger
#       8     no_directories=True, # Si True, télécharge les fichiers dans le répertoire de sortie sans créer de sous-répertoires
#       9 )
#      11 pprint(f"List of saved files: {get_result}")
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/site-packages/copernicusmarine/core_functions/deprecated_options.py:78, in deprecated_python_option.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#      75 @functools.wraps(f)
#      76 def wrapper(*args, **kwargs):
#      77     rename_kwargs(f.__name__, kwargs, aliases)
# ---> 78     return f(*args, **kwargs)
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/site-packages/copernicusmarine/python_interface/exception_handler.py:13, in log_exception_and_exit.<locals>.wrapper(*args, **kwargs)
#      10 @wraps(function)
#      11 def wrapper(*args, **kwargs):
#      12     try:
# ---> 13         return function(*args, **kwargs)
#      14     except click.Abort:
#      15         print("Abort")
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/site-packages/copernicusmarine/python_interface/get.py:129, in get(dataset_id, dataset_version, dataset_part, username, password, no_directories, output_directory, credentials_file, overwrite, request_file, filter, regex, file_list, create_file_list, index_parts, sync, sync_delete, skip_existing, dry_run, max_concurrent_requests, disable_progress_bar, staging)
#     127 file_list = pathlib.Path(file_list) if file_list else None
#     128 request_file = pathlib.Path(request_file) if request_file else None
# --> 129 return get_function(
#     130     dataset_id=dataset_id,
#     131     force_dataset_version=dataset_version,
#     132     force_dataset_part=dataset_part,
#     133     username=username,
#     134     password=password,
#     135     no_directories=no_directories,
#     136     output_directory=output_directory,
#     137     credentials_file=credentials_file,
#     138     overwrite=overwrite,
#     139     request_file=request_file,
#     140     filter_option=filter,
#     141     regex=regex,
#     142     file_list_path=file_list,
#     143     create_file_list=create_file_list,
#     144     index_parts=index_parts,
#     145     sync=sync,
#     146     sync_delete=sync_delete,
#     147     skip_existing=skip_existing,
#     148     dry_run=dry_run,
#     149     max_concurrent_requests=max_concurrent_requests,
#     150     disable_progress_bar=disable_progress_bar,
#     151     staging=staging,
#     152 )
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/site-packages/copernicusmarine/core_functions/get.py:121, in get_function(dataset_id, force_dataset_version, force_dataset_part, username, password, no_directories, output_directory, credentials_file, overwrite, request_file, filter_option, regex, file_list_path, create_file_list, sync, sync_delete, index_parts, skip_existing, dry_run, max_concurrent_requests, disable_progress_bar, staging)
#     118 if create_file_list or dry_run:
#     119     get_request.dry_run = True
# --> 121 return _run_get_request(
#     122     username=username,
#     123     password=password,
#     124     get_request=get_request,
#     125     create_file_list=create_file_list,
#     126     credentials_file=credentials_file,
#     127     max_concurrent_requests=max_concurrent_requests,
#     128     disable_progress_bar=disable_progress_bar,
#     129     staging=staging,
#     130 )
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/site-packages/copernicusmarine/core_functions/get.py:158, in _run_get_request(username, password, get_request, create_file_list, credentials_file, max_concurrent_requests, disable_progress_bar, staging)
#     149 retrieval_service: RetrievalService = get_retrieval_service(
#     150     get_request.dataset_id,
#     151     get_request.force_dataset_version,
#    (...)
#     155     staging=staging,
#     156 )
#     157 get_request.dataset_url = retrieval_service.uri
# --> 158 downloaded_files = download_original_files(
#     159     username,
#     160     password,
#     161     get_request,
#     162     max_concurrent_requests,
#     163     disable_progress_bar,
#     164     create_file_list,
#     165 )
#     166 return downloaded_files
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/site-packages/copernicusmarine/download_functions/download_original_files.py:156, in download_original_files(username, password, get_request, max_concurrent_requests, disable_progress_bar, create_file_list)
#     154         filenames_in.append(s3_file.filename_in)
#     155         filenames_out.append(s3_file.filename_out)
# --> 156 download_files(
#     157     username,
#     158     endpoint,
#     159     bucket,
#     160     filenames_in,
#     161     filenames_out,
#     162     max_concurrent_requests,
#     163     disable_progress_bar,
#     164 )
#     165 return response
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/site-packages/copernicusmarine/download_functions/download_original_files.py:271, in download_files(username, endpoint_url, bucket, filenames_in, filenames_out, max_concurrent_requests, disable_progress_bar)
#     269         pathlib.Path.mkdir(parent_dir, parents=True)
#     270 if max_concurrent_requests:
# --> 271     run_concurrently(
#     272         _download_one_file,
#     273         [
#     274             (username, endpoint_url, bucket, in_file, str(out_file))
#     275             for in_file, out_file in zip(
#     276                 filenames_in,
#     277                 filenames_out,
#     278             )
#     279         ],
#     280         max_concurrent_requests,
#     281         tdqm_bar_configuration={
#     282             "disable": disable_progress_bar,
#     283             "desc": "Downloading files",
#     284         },
#     285     )
#     286 else:
#     287     logger.info("Downloading files one by one...")
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/site-packages/copernicusmarine/core_functions/utils.py:134, in run_concurrently(func, function_arguments, max_concurrent_requests, tdqm_bar_configuration)
#     129 out = []
#     130 with tqdm(
#     131     total=len(function_arguments),
#     132     **tdqm_bar_configuration,
#     133 ) as pbar:
# --> 134     with concurrent.futures.ThreadPoolExecutor(
#     135         max_workers=max_concurrent_requests
#     136     ) as executor:
#     137         future_to_url = (
#     138             executor.submit(func, *function_argument)
#     139             for function_argument in function_arguments
#     140         )
#     141         for future in concurrent.futures.as_completed(future_to_url):
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/concurrent/futures/thread.py:239, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     237 if wait:
#     238     for t in self._threads:
# --> 239         t.join()
#
# File /opt/anaconda3/envs/env-croco/lib/python3.13/threading.py:1092, in Thread.join(self, timeout)
#    1089 if timeout is not None:
#    1090     timeout = max(timeout, 0)
# -> 1092 self._handle.join(timeout)
#
# KeyboardInterrupt:
